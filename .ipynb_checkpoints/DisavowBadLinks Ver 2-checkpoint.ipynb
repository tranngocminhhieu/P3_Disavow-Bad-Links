# %% [markdown]
# # Extracting lists to Disavow links on Gooogle Search Console
#
# My website ([LucidGen.com](https://lucidgen.com)) is getting many backlinks of unknown origin. Someone is attacking my website by giving me many bad backlinks. These things can badly affect my website ranking on Google Search. So I need to find bad backlinks in all of the backlinks to tell with Google that is not mine and require Google to exclude it from counting backlinks for my website.
#
# **How I do it:**
# I'll export data from Ahref (backlinks), MOZ (Spam Score), Search Console (Top linking sites) and combine them into one dataset.
# I also gather some lists for conditions such as Domain White List, Posts Sitemap, Bad Keywords for Domain, and Bad Keywords for Path.
#
# I'll extract Manual Check by use conditions:
# - Domain and path not in bad keywords, path not contain my post's path
# - Domain Authority (DA) > 15 and Spam Score (SS) < DA*20% < 10%
# - Domain Rating (DR) > 30 and Domain Traffic (DT) > 3000
#
# All the remaining domains I will add to the Disavow list.
#
# **Summary of results:**
# I get three final lists:
# - **Disavow list:** I'll send it to Google Search Console.
# - **DMCA Report list:** I'll report to Google Copyright Removal because they infringe my content.
# - **Manual Check List:** I need to check because they don't match any conditions. I can use Ahref Quick Batch Analysis to find their DA and add bad backlinks to Disavow list.
#
#
# ## Exploring datasets & lists
#
# ### Exploring datasets
#
# #### Ahref dataset
# I'll export it from Ahref > Site Explorer > Backlinks.

# %%
# Exploring Ahref dataset
import pandas as pd
explore_dataset_ahref = pd.read_csv('Input/Dataset_Ahref.csv')
explore_dataset_ahref
# Out:
#                                    Referring page title  \
# 0                  Học làm website với WordPress cơ bản
# 1     Thach Pham – Chuyên trang chia sẻ các kiến thứ...
# 2       Cài website WordPress trên localhost dùng XAMPP
# 3     WordPress là gì? Vì sao nên dùng WordPress để ...
# 4     Học WooCommerce - Hướng dẫn dùng WooCommerce đ...
# ...                                                 ...
# 9440                 Verkkosivun katsaus | lucidgen.com
# 9441         7 themes WordPress trả phí có giá cao nhất
# 9442  Hiểu và sử dụng tốt sức mạnh của Link nội để l...
# 9443                    Merge Multiple Csv Files Python
# 9444                   Webseiten-Bericht | lucidgen.com
#
#                                      Referring page URL Language  \
# 0     https://thachpham.com/wordpress/wordpress-tuto...       vi
# 1                                https://thachpham.com/       vi
# 2     https://thachpham.com/wordpress/wordpress-tuto...       vi
# 3     https://thachpham.com/wordpress/wordpress-tuto...       vi
# 4          https://thachpham.com/series/hoc-woocommerce       vi
# ...                                                 ...      ...
# 9440   https://www.website-scan.com/fi/www/lucidgen.com       fi
# 9441  https://thachpham.com/wordpress/themes-wordpre...       vi
# 9442  https://thachpham.com/seo/hieu-va-su-dung-tot-...      NaN
# 9443  https://www.bestschoolrankings.com/school/merg...       en
# 9444   https://www.website-scan.com/de/www/lucidgen.com       de
#
#                   Platform  Referring page HTTP code  Domain rating  \
# 0                wordpress                       200           67.0
# 1                wordpress                       200           67.0
# 2                wordpress                       200           67.0
# 3                wordpress                       200           67.0
# 4     ecommerce, wordpress                       200           67.0
# ...                    ...                       ...            ...
# 9440                   NaN                       200           29.0
# 9441             wordpress                       200           67.0
# 9442             wordpress                       200           67.0
# 9443                   NaN                       200            5.0
# 9444                   NaN                       200           29.0
#
#       Domain traffic  Referring domains  Linked domains  External links  ...  \
# 0              32068                 64              11              16  ...
# 1              32068                560              11              14  ...
# 2              32068                 28              12              17  ...
# 3              32068                 24              15              23  ...
# 4              32068                 36              10              11  ...
# ...              ...                ...             ...             ...  ...
# 9440            6084                  0              10              65  ...
# 9441           32068                  0              23              41  ...
# 9442           32068                  0              12              21  ...
# 9443            2684                  0              23              33  ...
# 9444            6084                  0              10              65  ...
#
#       Content  Nofollow    UGC Sponsored Rendered   Raw      Lost status  \
# 0       False     False  False     False    False  True              NaN
# 1       False     False  False     False    False  True              NaN
# 2       False     False  False     False     True  True              NaN
# 3       False     False  False     False    False  True              NaN
# 4       False     False  False     False    False  True              NaN
# ...       ...       ...    ...       ...      ...   ...              ...
# 9440    False      True  False     False    False  True              NaN
# 9441    False     False  False     False    False  True              NaN
# 9442    False     False  False     False    False  True              NaN
# 9443    False      True  False     False    False  True  removedfromhtml
# 9444    False      True  False     False    False  True              NaN
#
#                First seen            Last seen                 Lost
# 0     2021-07-22 09:25:45  2021-12-06 02:38:27                  NaN
# 1     2021-10-11 09:11:28  2021-11-16 18:57:31                  NaN
# 2     2021-07-17 20:20:22  2021-12-28 00:19:10                  NaN
# 3     2021-07-18 01:18:57  2021-12-27 04:06:05                  NaN
# 4     2021-10-29 23:16:06  2021-12-19 08:34:28                  NaN
# ...                   ...                  ...                  ...
# 9440  2021-07-06 08:39:12  2021-10-10 01:35:52                  NaN
# 9441  2021-07-19 03:30:44  2021-12-27 02:13:53                  NaN
# 9442  2021-07-20 02:40:42  2021-12-26 17:25:37                  NaN
# 9443  2021-12-01 14:39:51  2021-12-01 14:39:51  2021-12-12 15:59:53
# 9444  2021-07-28 18:21:22  2021-10-10 01:07:52                  NaN
#
# [9445 rows x 27 columns]

# %% [markdown]
# I'll use `Referring page URL` and `Domain Rating` from Ahref dataset.

# %% [markdown]
# #### Google Seach Console dataset
# I'll export it from Search Console > Links > Top linking sites.

# %%
# Exploring Console dataset
explore_dataset_console = pd.read_csv('Input/Dataset_Console.csv')
explore_dataset_console
# Out:
#                    Site  Linking pages  Target pages
# 0          huuthuan.net           8492             1
# 1         thachpham.com           4739             1
# 2            medium.com            926           102
# 3         microsoft.com            345             4
# 4            alotoi.com            309             1
# ..                  ...            ...           ...
# 322           turtc.com              1             1
# 323    asyabahis417.com              1             1
# 324      laptopvang.com              1             1
# 325  selfstation.org.pl              1             1
# 326     source1net.info              1             1
#
# [327 rows x 3 columns]

# %% [markdown]
# I'll use only `Site` from Console dataset.

# %% [markdown]
# #### MOZ dataset
# I'll export it from Moz Pro > Link Research > Spam Score.
# Because the MOZ dataset has many redundant rows, I have to use another way to view, and I will delete these rows later.

# %%
#Exploring Moz dataset
from csv import reader
open_file = open('Input/Dataset_Moz.csv')
read_file = reader(open_file)
explore_dataset_moz = list(read_file)

for row in explore_dataset_moz[0:10]:
    print(row)
# Out:
# ['\ufeff------------------------------------------------------------------------']
# ['Inbound Links by Spam Score for', 'lucidgen.com']
# ['Scope', 'pld']
# ['Sorted by', 'spam_score']
# ['------------------------------------------------------------------------']
# []
# ['URL', 'Title', 'Anchor Text', 'Spam Score', 'DA', 'Date First Seen', 'Date Crawled']
# ['www.10k.pw/domain-list-511', '', 'lucidgen.com', '96%', '3', '2021-07-27', '2021-10-30']
# ['www.100k.pw/domain-list-511', '', 'lucidgen.com', '96%', '2', '2021-07-25', '2021-10-24']
# ['www.new.net.in/domain-list-58', 'Alexa top domain list ||  page  58', 'lucidgen.com', '88%', '20', '2021-05-10', '2021-09-24']

# %% [markdown]
# I'll use `URL`, `Spam Score`, and `DA` from MOZ dataset.

# %% [markdown]
# ### Exploring the list of uses for the condition
#
# I'll prepare some simple lists with one column and no header:
# - **Domain White List:** I use it to exclude the domains from conditions.
# - **Posts Sitemap:** I export it from the website sitemap.
# - **Bad Keywords for Domain:** For example, top, free, list, domain, .pw, etc.
# - **Bad keywords for Path:** For example, list, top, web-site-no, etc.

# %%
#Exploring the list of uses for the condition.
list_whitelist = pd.read_csv('Input/List_DomainWhitelist.csv',header=None).values.tolist()
list_sitemap = pd.read_csv('Input/List_PostsSitemap.csv',header=None).values.tolist()
list_key_domain = pd.read_csv('Input/List_BadKeyDomain.csv',header=None).values.tolist()
list_key_path = pd.read_csv('Input/List_BadKeyPath.csv',header=None).values.tolist()

print('Domain whitelist:')
print(pd.DataFrame(list_whitelist))
print('\nOur post sitemap:')
print(pd.DataFrame(list_sitemap))
print('\nBad keywords for domain:')
print(pd.DataFrame(list_key_domain))
print('\nBad keywords for path:')
print(pd.DataFrame(list_key_path))
# Out:
# Domain whitelist:
#                       0
# 0              about.me
# 1    analyticsmania.com
# 2           behance.net
# 3         business.site
# 4     cellphones.com.vn
# ..                  ...
# 699        academia.edu
# 700        stanford.edu
# 701     webhoanggia.com
# 702     cgscomputer.com
# 703          linode.com
#
# [704 rows x 1 columns]
#
# Our post sitemap:
#                                                      0
# 0    https://lucidgen.com/en/how-to-add-watermark-t...
# 1    https://lucidgen.com/cach-tat-che-do-da-xem-va...
# 2    https://lucidgen.com/khang-trang-khong-duoc-ph...
# 3    https://lucidgen.com/ban-tai-khoan-quang-cao-f...
# 4    https://lucidgen.com/auto-phan-mem-ket-ban-fac...
# ..                                                 ...
# 195  https://lucidgen.com/cai-mail-cong-ty-vao-outl...
# 196  https://lucidgen.com/gia-lap-may-tinh-casio-fx...
# 197       https://lucidgen.com/co-nen-mua-ten-mien-vn/
# 198  https://lucidgen.com/loi-lien-ket-ban-theo-doi...
# 199   https://lucidgen.com/chuyen-ladipage-ve-hosting/
#
# [200 rows x 1 columns]
#
# Bad keywords for domain:
#            0
# 0          -
# 1       .biz
# 2        .in
# 3   .info.pl
# 4        .pl
# 5        .pw
# 6       .xyz
# 7       baby
# 8   backlink
# 9       best
# 10     check
# 11    coupon
# 12    domain
# 13      find
# 14      free
# 15      fuck
# 16       jav
# 17   keyword
# 18       kid
# 19      link
# 20      list
# 21     login
# 22     mega1
# 23      porn
# 24      rank
# 25       sex
# 26       top
# 27       url
# 28   website
# 29       xxx
# 30       .tk
#
# Bad keywords for path:
#              0
# 0         list
# 1          top
# 2  web-site-no

# %% [markdown]
# ## Converting the datasets to a list of lists

# %%
# Converting the datasets to a list of lists
dataset_ahref = explore_dataset_ahref.values.tolist()
dataset_console = explore_dataset_console.values.tolist()
dataset_moz = explore_dataset_moz[7:]

print('First data row in Ahref:')
print(dataset_ahref[0])
print('\nFirst data row in Console:')
print(dataset_console[0])
print('\nFirst data row in Moz:')
print(dataset_moz[0])
# Out:
# First data row in Ahref:
# ['Học làm website với WordPress cơ bản', 'https://thachpham.com/wordpress/wordpress-tutorials/serie-hoc-wordpress-co-ban.html', 'vi', 'wordpress', 200, 67.0, 32068, 64, 11, 16, 2147, 143, 'https://lucidgen.com/', nan, 'Lucid Gen', nan, 'text', False, False, False, False, False, True, nan, '2021-07-22 09:25:45', '2021-12-06 02:38:27', nan]
#
# First data row in Console:
# ['huuthuan.net', 8492, 1]
#
# First data row in Moz:
# ['www.10k.pw/domain-list-511', '', 'lucidgen.com', '96%', '3', '2021-07-27', '2021-10-30']

# %% [markdown]
# ## Extracting the required data for datasets
#
# I need to combine all of the datasets into one with columns: Domain, URL, Path, Domain Rating (DR), Domain Authority (DA), Spam Score (SS). So I need to extract some required columns from the datasets.
# - **Ahref:** Domain, URL, Path, DR.
# - **MOZ:** Domain, URL, Path, DA, SS.
# - **Console:** Domain.
#
# And to use for extract conditions, I also extract paths from the posts sitemap.

# %%
# For extracting TLD domain (Root domain)
import tldextract #We need install tldextract module before import it
# For extracting path in URL
from urllib.parse import urlparse

# Extracting the required data for Ahref dataset
dataset_ahref_extracted = []

for row in dataset_ahref:
    page = row[1]
    domain = tldextract.extract(page).registered_domain
    dr = float(row[5])
    dt = int(row[6])
    path = urlparse(page).path
    url = urlparse(page).netloc + urlparse(page).path # Remove HTTP/HTTPS to combine datasets later
    data = [domain,url,path,dr,dt]
    if data not in dataset_ahref_extracted and domain != '':
        dataset_ahref_extracted.append(data)

# Extracting the required data for Moz dataset
dataset_moz_extracted = []

for row in dataset_moz:
    page = 'https://'+row[0] # urlparse requires HTTP/HTTPS for URL, but MOZ doesn't have.
    domain = tldextract.extract(page).registered_domain
    da = float(row[4])
    ss = row[3].replace('%','')
    if ss == '--':
        ss = 0.0
    else:
        ss = float(ss)
    path = urlparse(page).path
    url = urlparse(page).netloc + urlparse(page).path # Remove HTTP/HTTPS to combine datasets later
    data = [domain,url,path,da,ss]
    if data not in dataset_moz_extracted and domain != '':
        dataset_moz_extracted.append(data)

# Extracting the domains for Console dataset
dataset_console_domain = []

for row in dataset_console:
    domain = row[0]
    if domain not in dataset_console_domain:
        dataset_console_domain.append([domain])

# Extracting the paths for the posts sitemap list
for row in list_sitemap:
    row[0] = urlparse(row[0]).path.replace('en/','').replace('/','')

print('Ahref dataset:')
pd.DataFrame(dataset_ahref_extracted,columns=['Domain','URL','Path','Domain Rating (DR)','Domain Traffic (DT)'])
# Out:
# Ahref dataset:
#                       Domain  \
# 0              thachpham.com
# 1              thachpham.com
# 2              thachpham.com
# 3              thachpham.com
# 4              thachpham.com
# ...                      ...
# 5979       isheetworkbase.co
# 5980           thachpham.com
# 5981           thachpham.com
# 5982           thachpham.com
# 5983  bestschoolrankings.com
#
#                                                     URL  \
# 0     thachpham.com/wordpress/wordpress-tutorials/se...
# 1                                        thachpham.com/
# 2     thachpham.com/wordpress/wordpress-tutorials/ca...
# 3     thachpham.com/wordpress/wordpress-tutorials/wo...
# 4                  thachpham.com/series/hoc-woocommerce
# ...                                                 ...
# 5979  bachelor.isheetworkbase.co/merging-files-in-ex...
# 5980  thachpham.com/wordpress/wp-plugin/tao-trang-ba...
# 5981  thachpham.com/wordpress/themes-wordpress/theme...
# 5982  thachpham.com/seo/hieu-va-su-dung-tot-suc-manh...
# 5983  www.bestschoolrankings.com/school/merge-multip...
#
#                                                    Path  Domain Rating (DR)  \
# 0     /wordpress/wordpress-tutorials/serie-hoc-wordp...                67.0
# 1                                                     /                67.0
# 2     /wordpress/wordpress-tutorials/cai-wordpress-l...                67.0
# 3     /wordpress/wordpress-tutorials/wordpress-la-gi...                67.0
# 4                               /series/hoc-woocommerce                67.0
# ...                                                 ...                 ...
# 5979  /merging-files-in-excel/69/new-excel-merging-u...                 0.4
# 5980  /wordpress/wp-plugin/tao-trang-ban-san-pham-so...                67.0
# 5981  /wordpress/themes-wordpress/themes-gia-cao-nha...                67.0
# 5982  /seo/hieu-va-su-dung-tot-suc-manh-cua-link-noi...                67.0
# 5983            /school/merge-multiple-csv-files-python                 5.0
#
#       Domain Traffic (DT)
# 0                   32068
# 1                   32068
# 2                   32068
# 3                   32068
# 4                   32068
# ...                   ...
# 5979                    4
# 5980                32068
# 5981                32068
# 5982                32068
# 5983                 2684
#
# [5984 rows x 5 columns]

# %%
print('MOZ dataset:')
pd.DataFrame(dataset_moz_extracted,columns=['Domain','URL','Path','Domain Authority (DA)','Spam Score (SS)'])
# Out:
# MOZ dataset:
#              Domain                                                URL  \
# 0            10k.pw                         www.10k.pw/domain-list-511
# 1           100k.pw                        www.100k.pw/domain-list-511
# 2        new.net.in                      www.new.net.in/domain-list-58
# 3        one.net.in                      www.one.net.in/domain-list-58
# 4       weblists.pw                    www.weblists.pw/domain-list-511
# ...             ...                                                ...
# 7622  wordpress.com      minhhieuhcm.wordpress.com/category/di-chuyen/
# 7623  wordpress.com  minhhieuhcm.wordpress.com/2016/12/21/huong-dan...
# 7624  wordpress.com  minhhieuhcm.wordpress.com/category/phan-mem-va...
# 7625  justanote.xyz  justanote.xyz/cach-xuat-san-pham-tren-wordpres...
# 7626  justanote.xyz  justanote.xyz/cong-cu-chia-nhom-tu-khoa-google...
#
#                                                    Path  \
# 0                                      /domain-list-511
# 1                                      /domain-list-511
# 2                                       /domain-list-58
# 3                                       /domain-list-58
# 4                                      /domain-list-511
# ...                                                 ...
# 7622                               /category/di-chuyen/
# 7623  /2016/12/21/huong-dan-giai-bai-tap-dinh-gia-co...
# 7624                      /category/phan-mem-van-phong/
# 7625  /cach-xuat-san-pham-tren-wordpress-cho-merchan...
# 7626             /cong-cu-chia-nhom-tu-khoa-google-ads/
#
#       Domain Authority (DA)  Spam Score (SS)
# 0                       3.0             96.0
# 1                       2.0             96.0
# 2                      20.0             88.0
# 3                      22.0             88.0
# 4                       4.0             86.0
# ...                     ...              ...
# 7622                    2.0              0.0
# 7623                    2.0              0.0
# 7624                    2.0              0.0
# 7625                    1.0              0.0
# 7626                    1.0              0.0
#
# [7627 rows x 5 columns]

# %%
print('Console dataset:')
pd.DataFrame(dataset_console_domain,columns=['Domain'])
# Out:
# Console dataset:
#                  Domain
# 0          huuthuan.net
# 1         thachpham.com
# 2            medium.com
# 3         microsoft.com
# 4            alotoi.com
# ..                  ...
# 322           turtc.com
# 323    asyabahis417.com
# 324      laptopvang.com
# 325  selfstation.org.pl
# 326     source1net.info
#
# [327 rows x 1 columns]

# %%
print('Posts sitemap:')
pd.DataFrame(list_sitemap,columns=['Path'])
# Out:
# Posts sitemap:
#                                                   Path
# 0                        how-to-add-watermark-to-photo
# 1        cach-tat-che-do-da-xem-va-thong-bao-tren-zalo
# 2                khang-trang-khong-duoc-phep-quang-cao
# 3                     ban-tai-khoan-quang-cao-facebook
# 4                       auto-phan-mem-ket-ban-facebook
# ..                                                 ...
# 195  cai-mail-cong-ty-vao-outlook-tren-dien-thoai-v...
# 196  gia-lap-may-tinh-casio-fx-580vn-plus-fx-570vn-...
# 197                             co-nen-mua-ten-mien-vn
# 198               loi-lien-ket-ban-theo-doi-da-het-han
# 199                         chuyen-ladipage-ve-hosting
#
# [200 rows x 1 columns]

# %% [markdown]
# ## Merging all datasets into one
#
# ### Step 1: Merging distinct domain, URL, Path
# Ahref and MOZ datasets have the domain, URL, and Path. But Console dataset does not. So I'll merge Ahref and MOZ first and then Console.

# %%
# Merging Ahref and MOZ datasets
dataset_merged_domain_url_path = []
for row in dataset_ahref_extracted + dataset_moz_extracted:
    domain = row[0]
    url = row[1]
    path = row[2]
    data = [domain,url,path]
    if data not in dataset_merged_domain_url_path:
        dataset_merged_domain_url_path.append(data)

#Merging Console domain to merged Ahref and MOZ dataset
dataset_ahref_moz_domain = []
for row in dataset_merged_domain_url_path:
    domain = row[0]
    if domain not in dataset_ahref_moz_domain:
        dataset_ahref_moz_domain.append(domain)

for domain in dataset_console_domain:
    if domain not in dataset_ahref_moz_domain:
        dataset_merged_domain_url_path.append([domain[0],'None','None'])

# Sorting dataset_merged_domain_url_path by domain
dataset_merged_domain_url_path = sorted(dataset_merged_domain_url_path)

pd.DataFrame(dataset_merged_domain_url_path,columns=['Domain','URL','Path'])
# Out:
#               Domain                                                URL  \
# 0            100k.pw                        www.100k.pw/domain-list-511
# 1           10id.com           www.10id.com/googlewebmasters/10784.html
# 2             10k.pw                         www.10k.pw/domain-list-511
# 3       117vn.online                                      117vn.online/
# 4          12bor.com  12bor.com/vi-sao-luot-dang-ky-kenh-youtube-bi-...
# ...              ...                                                ...
# 10610    youtube.com                                               None
# 10611    zalopc.chat  www.zalopc.chat/2021/12/10-cach-bat-bao-ve-fac...
# 10612     zoacum.com                       zoacum.com/website-list-821/
# 10613  zonealarm.com                                               None
# 10614    zoomcem.com  learning.zoomcem.com/ehpbdww/batch-script-to-c...
#
#                                                     Path
# 0                                       /domain-list-511
# 1                           /googlewebmasters/10784.html
# 2                                       /domain-list-511
# 3                                                      /
# 4      /vi-sao-luot-dang-ky-kenh-youtube-bi-giam-khac...
# ...                                                  ...
# 10610                                               None
# 10611  /2021/12/10-cach-bat-bao-ve-facebook-tren-ien....
# 10612                                 /website-list-821/
# 10613                                               None
# 10614  /ehpbdww/batch-script-to-compare-two-csv-files...
#
# [10615 rows x 3 columns]

# %% [markdown]
# ### Step 2: Merging all data into one dataset
# Now, I can merge all data into one dataset with columns: Domain | URL | Path | DR | DT | DA | SS | Disavow.

# %%
#Merging all data into one dataset
dataset_group = []
for row in dataset_merged_domain_url_path:
    domain = row[0]
    url = row[1]
    path = row[2]
    data = [domain,url,path,'None','None','None','None','domain:'+domain]

    # Get DR from Ahref
    for a_row in dataset_ahref_extracted:
        a_domain = a_row[0]
        a_dr = a_row[3]
        a_dt = a_row[4]
        if domain == a_domain:
            data[3] = a_dr
            data[4] = a_dt

    # Get DA and SS from MOZ
    for m_row in dataset_moz_extracted:
        m_domain = m_row[0]
        m_da = m_row[3]
        m_ss = m_row[4]
        if domain == m_domain:
            data[5] = m_da
            data[6] = m_ss

    dataset_group.append(data)

pd.DataFrame(dataset_group,columns=['Domain','URL','Path','DR','DT','DA','SS','Disavow'])
# Out:
#               Domain                                                URL  \
# 0            100k.pw                        www.100k.pw/domain-list-511
# 1           10id.com           www.10id.com/googlewebmasters/10784.html
# 2             10k.pw                         www.10k.pw/domain-list-511
# 3       117vn.online                                      117vn.online/
# 4          12bor.com  12bor.com/vi-sao-luot-dang-ky-kenh-youtube-bi-...
# ...              ...                                                ...
# 10610    youtube.com                                               None
# 10611    zalopc.chat  www.zalopc.chat/2021/12/10-cach-bat-bao-ve-fac...
# 10612     zoacum.com                       zoacum.com/website-list-821/
# 10613  zonealarm.com                                               None
# 10614    zoomcem.com  learning.zoomcem.com/ehpbdww/batch-script-to-c...
#
#                                                     Path    DR    DT    DA  \
# 0                                       /domain-list-511   0.5     0   2.0
# 1                           /googlewebmasters/10784.html   9.0    13  None
# 2                                       /domain-list-511   0.4     0   3.0
# 3                                                      /   0.0     0  None
# 4      /vi-sao-luot-dang-ky-kenh-youtube-bi-giam-khac...  None  None   4.0
# ...                                                  ...   ...   ...   ...
# 10610                                               None  None  None  None
# 10611  /2021/12/10-cach-bat-bao-ve-facebook-tren-ien....   0.3     0  None
# 10612                                 /website-list-821/  61.0     9  59.0
# 10613                                               None  None  None  None
# 10614  /ehpbdww/batch-script-to-compare-two-csv-files...  32.0   478  None
#
#          SS               Disavow
# 0      96.0        domain:100k.pw
# 1      None       domain:10id.com
# 2      96.0         domain:10k.pw
# 3      None   domain:117vn.online
# 4      35.0      domain:12bor.com
# ...     ...                   ...
# 10610  None    domain:youtube.com
# 10611  None    domain:zalopc.chat
# 10612  12.0     domain:zoacum.com
# 10613  None  domain:zonealarm.com
# 10614  None    domain:zoomcem.com
#
# [10615 rows x 8 columns]

# %% [markdown]
# I feel satisfied with this complete dataset. Now I can use it with many conditions to extract to Disavow list.
#
# ## Extracting bad domains to Disavow list and DMCA report list
#
# **Conditions for defining a bad domain:**
# - Domain and path not in bad keywords, path not contain my post's path
# - Domain Authority (DA) > 15 and Spam Score (SS) < DA*20% < 10%
# - Domain Rating (DR) > 30 and Domain Traffic (DT) > 3000
#
# **Conditions for defining a URL infringing content:**
# - The path matches my post's path.
#
# ### Step 1: Creating some functions for conditions
# - is_bad_domain: The domain contains a bad keyword.
# - is_bad_path: The path contains a bad key keyword.
# - is_copied_path: The path matches my post's path.

# %%
## Checking if the domain contains a bad keyword
def is_bad_domain(domain):
    for row in list_key_domain:
        keyword = row[0]
        if '.' in keyword: # Checking suffix exactly ('.in' keyword will not match '.info' suffix)
            if tldextract.extract(domain).suffix in keyword:
                return True
        elif keyword in domain:
            return True
    return False

## Checking if the path contains a bad keyword
def is_bad_path(path):
    for row in list_key_path:
        keyword = row[0]
        if keyword in path:
            return True
    return False

## Checking if the path matches my post's path
def is_copied_path(path):
    for row in list_sitemap:
        post = row[0]
        if post in path:
            return True
    return False

print('Bad domain test:',is_bad_domain('abc.pw'))
print('Bad path test:',is_bad_path('domain-list.html'))
print('Matches path test:',is_copied_path('/digital-marketing/chuyen-doi-tawk-to.html'))
# Out:
# Bad domain test: True
# Bad path test: True
# Matches path test: True

# %% [markdown]
# ### Step 2: Extracting bad domains to Disavow list, DMCA report list, and Manual Check list

# %%
# Extracting bad domains to Disavow list, DMCA report list, and Manual Check list
disavow = []
dmca_report = []
manual_check = []

for row in dataset_group:
    domain = row[0]
    path = row[2]
    dr = row[3]
    dt = row[4]
    da = row[5]
    ss = row[6]
    dis = [row[7],dr,dt,da,ss] #Removing URL and Path for Disavow list

    #Checking if domain in white list
    if [domain] in list_whitelist:
        pass

    #Checking if path matches my post's path
    elif is_copied_path(path):
        disavow.append(dis)
        dmca_report.append(row)

    #Checking if domain and path contain a bad keyword
    elif not is_bad_domain(domain) and not is_bad_path(path):
        if dr != 'None' and dr > 30 and dt != 'None' and dt > 3000:
            manual_check.append(row)
        elif da != 'None' and da > 15 and ss != 'None' and ss < da*0.2 and ss < 0.1:
            manual_check.append(row)
        else:
            disavow.append(dis)
    else:
        disavow.append(dis)


#Removing duplicated rows for Disavow list
disavow_distinct = pd.DataFrame(disavow).drop_duplicates().values.tolist()

header_disavow = ['Disavow domain','DR','DT','DA','SS']
header_full = ['Domain','URL','Path','DR','DT','DA','SS','Disavow']

print('Disavow list:')
pd.DataFrame(disavow_distinct,columns=header_disavow)
# Out:
# Disavow list:
#                    Disavow domain    DR    DT    DA    SS
# 0                  domain:100k.pw   0.5     0   2.0  96.0
# 1                 domain:10id.com   9.0    13  None  None
# 2                   domain:10k.pw   0.4     0   3.0  96.0
# 3             domain:117vn.online   0.0     0  None  None
# 4                domain:12bor.com  None  None   4.0  35.0
# ...                           ...   ...   ...   ...   ...
# 1094  domain:yoursheetworkbase.co   0.0     0  None  None
# 1095           domain:zalopc.chat   0.3     0  None  None
# 1096            domain:zoacum.com  61.0     9  59.0  12.0
# 1097         domain:zonealarm.com  None  None  None  None
# 1098           domain:zoomcem.com  32.0   478  None  None
#
# [1099 rows x 5 columns]

# %% [markdown]
# Now I'll send the Disavow Domain column to Google Search Console. It is distinct (one line per domain).

# %%
print('DMCA report list:')
pd.DataFrame(dmca_report,columns=header_full)
# Out:
# DMCA report list:
#             Domain                                                URL  \
# 0          1gia.vn  1gia.vn/cach-ngan-chan-danh-cap-noi-dung-websi...
# 1       2048.click  2048.click/how-to-add-google-analytics-to-webs...
# 2        25giay.vn  25giay.vn/digital-marketing/chuyen-doi-tawk-to...
# 3       360baby.vn  360baby.vn/cach-ngan-chan-danh-cap-noi-dung-we...
# 4       360kids.vn  360kids.vn/cach-ngan-chan-danh-cap-noi-dung-we...
# ..             ...                                                ...
# 585  winbokids.com  www.winbokids.com/cach-ngan-chan-danh-cap-noi-...
# 586   winbokids.vn  winbokids.vn/cach-ngan-chan-danh-cap-noi-dung-...
# 587         wsg.vn  wsg.vn/nhan-mo-tai-khoan-quang-cao-bi-vo-hieu-...
# 588    yaamedia.vn  yaamedia.vn/tracking-chuyen-doi-tawk-to-bang-g...
# 589  yoolakids.com  yoolakids.com/cach-ngan-chan-danh-cap-noi-dung...
#
#                                                   Path    DR     DT    DA  \
# 0    /cach-ngan-chan-danh-cap-noi-dung-website-web-...  21.0      0  None
# 1             /how-to-add-google-analytics-to-website/  None   None   3.0
# 2           /digital-marketing/chuyen-doi-tawk-to.html  11.0  56134  30.0
# 3    /cach-ngan-chan-danh-cap-noi-dung-website-web-...  20.0      0  None
# 4    /cach-ngan-chan-danh-cap-noi-dung-website-web-...  21.0      0  None
# ..                                                 ...   ...    ...   ...
# 585  /cach-ngan-chan-danh-cap-noi-dung-website-web-...  21.0      0  None
# 586  /cach-ngan-chan-danh-cap-noi-dung-website-web-...  21.0      0  None
# 587  /nhan-mo-tai-khoan-quang-cao-bi-vo-hieu-hoa-bi...  23.0     19   5.0
# 588  /tracking-chuyen-doi-tawk-to-bang-google-tag-m...   0.0      0  None
# 589  /cach-ngan-chan-danh-cap-noi-dung-website-web-...  21.0      0  None
#
#        SS               Disavow
# 0    None        domain:1gia.vn
# 1    38.0     domain:2048.click
# 2     2.0      domain:25giay.vn
# 3    None     domain:360baby.vn
# 4    None     domain:360kids.vn
# ..    ...                   ...
# 585  None  domain:winbokids.com
# 586  None   domain:winbokids.vn
# 587  28.0         domain:wsg.vn
# 588  None    domain:yaamedia.vn
# 589  None  domain:yoolakids.com
#
# [590 rows x 8 columns]

# %% [markdown]
# I need to check if these URLs are infringing on my content. If true, I'll send it to Google Copyright Removal.

# %%
manual_check_distinct = len(pd.DataFrame(manual_check,columns=header_full).drop(['URL','Path','DR','DA','SS','Disavow'], axis=1).drop_duplicates().reset_index().values.tolist())

print('Manual check list: only',manual_check_distinct,'distinct domains')
pd.DataFrame(manual_check,columns=header_full)
# Out:
# Manual check list: only 19 distinct domains
#                 Domain                                                URL  \
# 0               1ty.vn  1ty.vn/Phai-Lam-Gi-Khi-May-Quet-Adobe-Khong-Ho...
# 1              aol.com                             search.aol.com/reviews
# 2    bingparachute.com                         s.bingparachute.com/search
# 3          bloggers.jp  ping.bloggers.jp/index.php/10,%208-1/article/1...
# 4          bloggers.jp  ping.bloggers.jp/index.php/10,%208-1/article/t...
# ..                 ...                                                ...
# 149        tntcode.com               domains.tntcode.com/ip/45.252.248.23
# 150        tntcode.com               domains.tntcode.com/ip/45.252.249.21
# 151      vnngaynay.net                                               None
# 152      vnngaynay.net  vnngaynay.net/phan-mem-lay-so-dien-thoai-faceb...
# 153       wipsites.com  www.wipsites.com/search/tai-mien-phi-office-20...
#
#                                                   Path    DR        DT    DA  \
# 0    /Phai-Lam-Gi-Khi-May-Quet-Adobe-Khong-Ho-tro-c...  44.0     65672  None
# 1                                             /reviews  91.0  32711987  None
# 2                                              /search   2.9         0  23.0
# 3        /index.php/10,%208-1/article/13/BestFiles.org  None      None  29.0
# 4    /index.php/10,%208-1/article/tatuirovki.198kaz...  None      None  29.0
# ..                                                 ...   ...       ...   ...
# 149                                  /ip/45.252.248.23  61.0      3033  36.0
# 150                                  /ip/45.252.249.21  61.0      3033  36.0
# 151                                               None  40.0     11429  34.0
# 152  /phan-mem-lay-so-dien-thoai-facebook-mien-phi-...  40.0     11429  34.0
# 153          /search/tai-mien-phi-office-2016-co-crack  None      None  28.0
#
#        SS                   Disavow
# 0    None             domain:1ty.vn
# 1    None            domain:aol.com
# 2     0.0  domain:bingparachute.com
# 3     0.0        domain:bloggers.jp
# 4     0.0        domain:bloggers.jp
# ..    ...                       ...
# 149  15.0        domain:tntcode.com
# 150  15.0        domain:tntcode.com
# 151   1.0      domain:vnngaynay.net
# 152   1.0      domain:vnngaynay.net
# 153   0.0       domain:wipsites.com
#
# [154 rows x 8 columns]

# %% [markdown]
# Because some domains don't have DA,DT, DR, SS, and Path, they do not match any conditions. I'll check it manually with Ahref Quick Batch Analysis to find their DA and add bad backlinks to Disavow list later.
#
# ## Saving three final lists to Excel files

# %%
#Saving three final lists to Excel files
pd.DataFrame(disavow_distinct).to_excel('Output/Disavow.xlsx',index=None,header=header_disavow)
pd.DataFrame(manual_check).to_excel('Output/ManualCheck.xlsx',index=None,header=header_full)
pd.DataFrame(dmca_report).to_excel('Output/DmcaReport.xlsx',index=None,header=header_full)

# %% [markdown]
# ## Conclusion
# I have gotten Disavow list, DMCA Report list, and Manual Check list. These lists can help me prevent bad backlinks attacks. I need to do this work once a week to protect my website rank on Google Search.
